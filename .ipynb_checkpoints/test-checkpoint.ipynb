# %%
import pandas as pd
df = pd.read_excel('WM Manager Dashboard Data SetV2.xlsx', sheet_name='Client Escalation', usecols=[0, 4, 9, 10, 11, 12])
clientEsc = df.transpose()
rows, columns = clientEsc.shape
clientlist = []

# %%
for inv in clientEsc:
        if clientEsc[inv]['Reason'] == 'Requested by client':
            clientlist.append(clientEsc[inv])
clientlist.sort(key=lambda d: d['Scheduled Date'])

# %%
iterator = 0
temp = []
for inv in clientEsc:
    if clientEsc[inv]['Type of Escalation'] == 'Severe':
        temp.append(clientEsc[inv])
temp.sort(key=lambda d:d['Performance'])
clientlist.extend(temp)
print(clientlist)

# %%
temp.clear()
for inv in clientEsc:
        if clientEsc[inv]['Type of Escalation'] == 'Moderate':
            temp.append(clientEsc[inv])
temp.sort(key=lambda d: d['Performance'])
clientlist.extend(temp)
print(clientlist)
# Out:
# [Investor Name         LAKESIDE NORTH BAY E
# Performance                        0.01584
# Reason                 Requested by client
# Description                            NaN
# Type of Escalation                  Severe
# Scheduled Date         2023-01-23 00:00:00
# Name: 11, dtype: object, Investor Name         AUTO MAKER OSHAWA A
# Performance                      0.787432
# Reason                Requested by client
# Description                           NaN
# Type of Escalation                 Severe
# Scheduled Date        2023-01-23 00:00:00
# Name: 15, dtype: object, Investor Name                   STELL HAMILTON D
# Performance                            -0.196281
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 0, dtype: object, Investor Name                AUTO MAKER OSHAWA C
# Performance                            -0.194227
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 1, dtype: object, Investor Name         AARON SPELLING TRUST CHARLIE & BOSLEY
# Performance                                       -0.187222
# Reason                                          Performance
# Description                      Poor portfolio performance
# Type of Escalation                                   Severe
# Scheduled Date                                          NaT
# Name: 2, dtype: object, Investor Name               LAKESIDE NORTH BAY M
# Performance                            -0.145926
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 3, dtype: object, Investor Name                AUTO MAKER OSHAWA E
# Performance                            -0.138462
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 4, dtype: object, Investor Name                   STELL HAMILTON S
# Performance                            -0.121423
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 5, dtype: object, Investor Name           CLIENT MONSIEUR
# Performance                    -0.097595
# Reason                       Market News
# Description           Impacted Portfolio
# Type of Escalation                Severe
# Scheduled Date                       NaT
# Name: 17, dtype: object, Investor Name                    FALLS NIAGARA M
# Performance                            -0.054346
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 18, dtype: object, Investor Name               LAKESIDE NORTH BAY C
# Performance                            -0.046929
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 19, dtype: object, Investor Name               LAKESHORE OAKVILLE C
# Performance                            -0.029217
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 20, dtype: object, Investor Name               LAKESIDE NORTH BAY A
# Performance                            -0.011494
# Reason                               Performance
# Description           Poor portfolio performance
# Type of Escalation                        Severe
# Scheduled Date                               NaT
# Name: 21, dtype: object, Investor Name         LAKESIDE NORTH BAY E
# Performance                        0.01584
# Reason                 Requested by client
# Description                            NaN
# Type of Escalation                  Severe
# Scheduled Date         2023-01-23 00:00:00
# Name: 11, dtype: object, Investor Name         AUTO MAKER OSHAWA M
# Performance                       0.16703
# Reason                        Market News
# Description            Impacted Portfolio
# Type of Escalation                 Severe
# Scheduled Date                        NaT
# Name: 13, dtype: object, Investor Name         AUTO MAKER OSHAWA A
# Performance                      0.787432
# Reason                Requested by client
# Description                           NaN
# Type of Escalation                 Severe
# Scheduled Date        2023-01-23 00:00:00
# Name: 15, dtype: object, Investor Name                  CLIENT MONSIEUR
# Performance                           -0.097595
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 6, dtype: object, Investor Name         FALLS NIAGARA M
# Performance                 -0.054346
# Reason                  Person Event
# Description             Career Change
# Type of Escalation           Moderate
# Scheduled Date                    NaT
# Name: 7, dtype: object, Investor Name              LAKESIDE NORTH BAY C
# Performance                           -0.046929
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 8, dtype: object, Investor Name         LAKESHORE OAKVILLE C
# Performance                      -0.029217
# Reason                       Person Event
# Description                   Family Death
# Type of Escalation                Moderate
# Scheduled Date                         NaT
# Name: 9, dtype: object, Investor Name             LAKESIDE NORTH BAY A
# Performance                          -0.011494
# Reason                CRM Trigerred discusions
# Description                    Buy new product
# Type of Escalation                    Moderate
# Scheduled Date                             NaT
# Name: 10, dtype: object, Investor Name                   FALLS NIAGARA A
# Performance                            0.112573
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 12, dtype: object, Investor Name               AUTO MAKER OSHAWA J
# Performance                             0.18111
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 14, dtype: object, Investor Name         STELL HAMILTON J
# Performance                    0.95837
# Reason                   Person Event
# Description                Inheritence
# Type of Escalation            Moderate
# Scheduled Date                     NaT
# Name: 16, dtype: object, Investor Name                  CLIENT MONSIEUR
# Performance                           -0.097595
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 6, dtype: object, Investor Name         FALLS NIAGARA M
# Performance                 -0.054346
# Reason                  Person Event
# Description             Career Change
# Type of Escalation           Moderate
# Scheduled Date                    NaT
# Name: 7, dtype: object, Investor Name              LAKESIDE NORTH BAY C
# Performance                           -0.046929
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 8, dtype: object, Investor Name         LAKESHORE OAKVILLE C
# Performance                      -0.029217
# Reason                       Person Event
# Description                   Family Death
# Type of Escalation                Moderate
# Scheduled Date                         NaT
# Name: 9, dtype: object, Investor Name             LAKESIDE NORTH BAY A
# Performance                          -0.011494
# Reason                CRM Trigerred discusions
# Description                    Buy new product
# Type of Escalation                    Moderate
# Scheduled Date                             NaT
# Name: 10, dtype: object, Investor Name                   FALLS NIAGARA A
# Performance                            0.112573
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 12, dtype: object, Investor Name               AUTO MAKER OSHAWA J
# Performance                             0.18111
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 14, dtype: object, Investor Name         STELL HAMILTON J
# Performance                    0.95837
# Reason                   Person Event
# Description                Inheritence
# Type of Escalation            Moderate
# Scheduled Date                     NaT
# Name: 16, dtype: object, Investor Name                  CLIENT MONSIEUR
# Performance                           -0.097595
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 6, dtype: object, Investor Name         FALLS NIAGARA M
# Performance                 -0.054346
# Reason                  Person Event
# Description             Career Change
# Type of Escalation           Moderate
# Scheduled Date                    NaT
# Name: 7, dtype: object, Investor Name              LAKESIDE NORTH BAY C
# Performance                           -0.046929
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 8, dtype: object, Investor Name         LAKESHORE OAKVILLE C
# Performance                      -0.029217
# Reason                       Person Event
# Description                   Family Death
# Type of Escalation                Moderate
# Scheduled Date                         NaT
# Name: 9, dtype: object, Investor Name             LAKESIDE NORTH BAY A
# Performance                          -0.011494
# Reason                CRM Trigerred discusions
# Description                    Buy new product
# Type of Escalation                    Moderate
# Scheduled Date                             NaT
# Name: 10, dtype: object, Investor Name                   FALLS NIAGARA A
# Performance                            0.112573
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 12, dtype: object, Investor Name               AUTO MAKER OSHAWA J
# Performance                             0.18111
# Reason                CRM Trigerred discussions
# Description                     Buy new product
# Type of Escalation                     Moderate
# Scheduled Date                              NaT
# Name: 14, dtype: object, Investor Name         STELL HAMILTON J
# Performance                    0.95837
# Reason                   Person Event
# Description                Inheritence
# Type of Escalation            Moderate
# Scheduled Date                     NaT
# Name: 16, dtype: object]
