# %%
from data_assessment.main import portfolios
port = portfolios[portfolios["Account"] == 1616655]
sum1 = port["Market_Value"].sum()
sum2 = port["Market_Value_as_of_31st_Dec_2022"].sum()
print(sum1,sum2)
port
# Out:
# 54809333.17 113470410.08999999
#      Advisor                          Investor_Name Investor_Type_Desc  \
# 0   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 1   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 2   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 3   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 4   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 5   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 6   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 7   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 8   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 9   Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 10  Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# 11  Gunasiri  AARON SPELLING TRUST CHARLIE & BOSLEY              TRUST
# ...
